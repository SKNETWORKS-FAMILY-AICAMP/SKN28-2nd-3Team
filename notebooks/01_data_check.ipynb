# %% [markdown]
# # 01_data_check

# %% [markdown]
# # 01. 원천 데이터 점검
#
# 본 단계에서는 원천 데이터의 구조와 품질을 사전에 확인한다.
# 모델링 이전에 데이터 상태를 정확히 파악하는 것은 이후 전처리, 피처 생성, 학습 결과 해석의 신뢰성을 높이기 위해 매우 중요하다.
#
# 주요 점검 항목은 다음과 같다.
#
# - 데이터셋별 행 수와 컬럼 수
# - 컬럼명 및 자료형
# - 결측치 존재 여부
# - 범주형 변수의 고유값 분포
# - 수치형 변수의 비정상값 여부
#
# 이 과정을 통해 원천 데이터에서 미리 보완해야 할 문제를 확인하고,
# 후속 분석 단계의 기준선을 정리한다.

# %% [markdown]
# ## 실행 내용
#
# 아래 코드는 `src.data.data_check` 모듈의 `main()` 함수를 호출하여
# 프로젝트에서 사용하는 원천 데이터를 일괄 점검한다.
#
# 노트북은 점검 과정을 직접 구현하기보다,
# 별도 모듈로 작성된 점검 로직을 실행하고 그 결과를 확인하는 역할을 한다.
# 이러한 방식은 동일한 점검 절차를 반복 가능하게 만들고,
# 프로젝트 전체 코드 구조를 보다 일관되게 유지하는 데 도움이 된다.

# %%
from src.data.data_check import main
main()
