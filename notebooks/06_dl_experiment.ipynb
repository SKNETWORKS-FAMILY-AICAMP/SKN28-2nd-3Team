# %% [markdown]
# # 06_dl_experiment

# %% [markdown]
# # 06. 딥러닝 모델 확장 실험
#
# 이 단계에서는 기존 머신러닝 베이스라인을 넘어
# 딥러닝 모델을 적용하여 추가적인 성능 향상 가능성을 실험한다.
#
# 머신러닝 모델은 비교적 해석이 용이하고 학습 속도가 빠르다는 장점이 있지만,
# 데이터의 복잡한 비선형 관계를 충분히 반영하지 못할 수도 있다.
# 반면 딥러닝 모델은 더 복잡한 패턴을 학습할 수 있으므로,
# 고객 이탈 문제에서도 추가적인 성능 개선 가능성을 탐색할 수 있다.
#
# 이 단계에서 수행하는 주요 작업은 다음과 같다.
#
# - 딥러닝 입력용 데이터셋 구성
# - 신경망 기반 분류 모델 설계 및 학습
# - 머신러닝 모델과의 성능 비교
# - 예측 성능과 해석 가능성 간의 균형 검토
#
# 이 실험의 목적은 단순히 더 복잡한 모델을 적용하는 것이 아니라,
# 딥러닝이 본 문제에서 실제로 의미 있는 개선을 제공하는지 검토하는 데 있다.

# %% [markdown]
# ## 실행 내용
#
# 아래 코드는 딥러닝 기반 고객 이탈 예측 모델을 학습하고
# 그 결과를 기존 머신러닝 모델과 비교하기 위한 과정을 실행한다.
#
# 이 노트북에서는 딥러닝 실험 흐름과 결과를 확인하는 역할을 담당하며,
# 세부 구현은 `src.models` 및 관련 데이터셋 생성 모듈에 정의되어 있다.
# 이를 통해 실험 과정을 재현 가능하게 유지하면서,
# 모델 확장에 따른 성능 변화와 한계를 함께 검토할 수 있다.
#
# 이 단계는 프로젝트를 단순 베이스라인 비교에서 끝내지 않고,
# 머신러닝과 딥러닝을 함께 검토한 확장형 분석으로 발전시키는 역할을 한다.

# %%
import pandas as pd
pd.read_csv("data/processed/train_table_dl.csv").head()
