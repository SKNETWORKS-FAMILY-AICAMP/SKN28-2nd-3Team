# %% [markdown]
# # 05_xai_analysis

# %% [markdown]
# # 05. XAI 기반 예측 결과 해석
#
# 이 단계에서는 학습된 머신러닝 모델의 예측 결과를 설명 가능한 형태로 해석한다.
#
# 고객 이탈 예측은 단순히 성능 지표가 높다고 해서 충분하지 않다.
# 실제 비즈니스 의사결정에 활용하려면, 어떤 고객이 왜 이탈 위험이 높다고 판단되었는지를 함께 설명할 수 있어야 한다.
# 즉, 예측 결과를 제시하는 것을 넘어 그 근거를 해석 가능한 방식으로 제공하는 것이 중요하다.
#
# 이 단계에서 중점적으로 다루는 내용은 다음과 같다.
#
# - 전체적으로 어떤 변수가 예측에 큰 영향을 주는지
# - 특정 고객의 예측 결과에 어떤 요인이 작용했는지
# - 이탈 확률을 높이는 방향과 낮추는 방향이 무엇인지
# - 모델이 실제 비즈니스 상식과 어느 정도 부합하는지
#
# 이러한 설명 가능성 분석은 모델을 단순한 예측 도구에 머물지 않게 하고,
# 실제 대응 전략을 설계할 수 있는 의사결정 지원 도구로 확장하는 데 의미가 있다.

# %% [markdown]
# ## 실행 내용
#
# 아래 코드는 학습된 모델을 바탕으로
# 전역 설명과 지역 설명을 포함한 XAI 분석을 수행한다.
#
# 이 노트북에서는 설명 결과를 확인하고 해석하는 역할을 담당하며,
# 세부 로직은 `src.xai` 영역에 모듈화되어 있다.
# 이를 통해 동일한 설명 과정을 반복 가능하게 하고,
# 모델 성능뿐 아니라 예측 근거까지 함께 분석할 수 있도록 구성하였다.
#
# 이 단계의 결과는 단순한 모델 비교를 넘어,
# 어떤 고객에게 어떤 방식의 리텐션 전략을 적용할 수 있을지 고민하는 해석의 기반이 된다.

# %%
from src.xai.shap_analysis import main
main()
